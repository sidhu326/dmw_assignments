# %% [markdown]
# <a href="https://colab.research.google.com/github/abhi4gupta/DMI/blob/main/Assignment2/deepSVDD_oneClassClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import torch
import numpy as np
from torch.utils import data
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from PIL import Image

def weights_init_normal(m):
    classname = m.__class__.__name__
    if classname.find("Conv") != -1 and classname != 'Conv':
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find("Linear") != -1:
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)
class MNIST_loader(data.Dataset):
    """This class is needed to processing batches for the dataloader."""
    def __init__(self, data, target, transform):
        self.data = data
        self.target = target
        self.transform = transform

    def __getitem__(self, index):
        """return transformed items."""
        x = self.data[index]
        y = self.target[index]
        if self.transform:
            x = Image.fromarray(x.numpy(), mode='L')
            x = self.transform(x)
        return x, y

    def __len__(self):
        """number of samples."""
        return len(self.data)


def get_mnist(args, data_dir='/content/drive/MyDrive/Data'):
    """get dataloders"""
    # min, max values for each class after applying GCN (as the original implementation)
    min_max = [(-0.8826567065619495, 9.001545489292527),
                (-0.6661464580883915, 20.108062262467364),
                (-0.7820454743183202, 11.665100841080346),
                (-0.7645772083211267, 12.895051191467457),
                (-0.7253923114302238, 12.683235701611533),
                (-0.7698501867861425, 13.103278415430502),
                (-0.778418217980696, 10.457837397569108),
                (-0.7129780970522351, 12.057777597673047),
                (-0.8280402650205075, 10.581538445782988),
                (-0.7369959242164307, 10.697039838804978)]

    transform = transforms.Compose([transforms.ToTensor(),
                                    transforms.Lambda(lambda x: global_contrast_normalization(x)),
                                    transforms.Normalize([min_max[args.normal_class][0]],
                                                         [min_max[args.normal_class][1] \
                                                         -min_max[args.normal_class][0]])])
    train = datasets.MNIST(root=data_dir, train=True, download=True)
    test = datasets.MNIST(root=data_dir, train=False, download=True)

    x_train = train.data
    y_train = train.targets

    x_train = x_train[np.where(y_train==args.normal_class)]
    y_train = y_train[np.where(y_train==args.normal_class)]
                                    
    data_train = MNIST_loader(x_train, y_train, transform)
    dataloader_train = DataLoader(data_train, batch_size=args.batch_size, 
                                  shuffle=True, num_workers=0)
    
    x_test = test.data
    y_test = test.targets
    y_test = np.where(y_test==args.normal_class, 0, 1)
    data_test = MNIST_loader(x_test, y_test, transform)
    dataloader_test = DataLoader(data_test, batch_size=args.batch_size, 
                                  shuffle=True, num_workers=0)
    return dataloader_train, dataloader_test

def global_contrast_normalization(x):
    """Apply global contrast normalization to tensor. """
    mean = torch.mean(x)  # mean over all features (pixels) per sample
    x -= mean
    x_scale = torch.mean(torch.abs(x))
    x /= x_scale
    return x

# %%
# !pip install barbar
# Out:
# Requirement already satisfied: barbar in /usr/local/lib/python3.7/dist-packages (0.2.1)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
from torch import optim
import torch.nn.functional as F
from sklearn.metrics import roc_auc_score
import numpy as np
from barbar import Bar
class network(nn.Module):
    def __init__(self, z_dim=32):
        super(network, self).__init__()
        self.pool = nn.MaxPool2d(2, 2)

        self.conv1 = nn.Conv2d(1, 8, 5, bias=False, padding=2)
        self.bn1 = nn.BatchNorm2d(8, eps=1e-04, affine=False)
        self.conv2 = nn.Conv2d(8, 4, 5, bias=False, padding=2)
        self.bn2 = nn.BatchNorm2d(4, eps=1e-04, affine=False)
        self.fc1 = nn.Linear(4 * 7 * 7, z_dim, bias=False)

    def forward(self, x):
        x = self.conv1(x)
        x = self.pool(F.leaky_relu(self.bn1(x)))
        x = self.conv2(x)
        x = self.pool(F.leaky_relu(self.bn2(x)))
        x = x.view(x.size(0), -1)
        return self.fc1(x)


class autoencoder(nn.Module):
    def __init__(self, z_dim=32):
        super(autoencoder, self).__init__()
        self.z_dim = z_dim
        self.pool = nn.MaxPool2d(2, 2)

        self.conv1 = nn.Conv2d(1, 8, 5, bias=False, padding=2)
        self.bn1 = nn.BatchNorm2d(8, eps=1e-04, affine=False)
        self.conv2 = nn.Conv2d(8, 4, 5, bias=False, padding=2)
        self.bn2 = nn.BatchNorm2d(4, eps=1e-04, affine=False)
        self.fc1 = nn.Linear(4 * 7 * 7, z_dim, bias=False)

        self.deconv1 = nn.ConvTranspose2d(2, 4, 5, bias=False, padding=2)
        self.bn3 = nn.BatchNorm2d(4, eps=1e-04, affine=False)
        self.deconv2 = nn.ConvTranspose2d(4, 8, 5, bias=False, padding=3)
        self.bn4 = nn.BatchNorm2d(8, eps=1e-04, affine=False)
        self.deconv3 = nn.ConvTranspose2d(8, 1, 5, bias=False, padding=2)
        
    def encode(self, x):
        x = self.conv1(x)
        x = self.pool(F.leaky_relu(self.bn1(x)))
        x = self.conv2(x)
        x = self.pool(F.leaky_relu(self.bn2(x)))
        x = x.view(x.size(0), -1)
        return self.fc1(x)
   
    def decode(self, x):
        x = x.view(x.size(0), int(self.z_dim / 16), 4, 4)
        x = F.interpolate(F.leaky_relu(x), scale_factor=2)
        x = self.deconv1(x)
        x = F.interpolate(F.leaky_relu(self.bn3(x)), scale_factor=2)
        x = self.deconv2(x)
        x = F.interpolate(F.leaky_relu(self.bn4(x)), scale_factor=2)
        x = self.deconv3(x)
        return torch.sigmoid(x)
        

    def forward(self, x):
        z = self.encode(x)
        x_hat = self.decode(z)
        return x_hat





class TrainerDeepSVDD:
    def __init__(self, args, data, device):
        self.args = args
        self.train_loader, self.test_loader = data
        self.device = device
    

    def pretrain(self):
        """ Pretraining the weights for the deep SVDD network using autoencoder"""
        ae = autoencoder(self.args.latent_dim).to(self.device)
        ae.apply(weights_init_normal)
        optimizer = optim.Adam(ae.parameters(), lr=self.args.lr_ae,
                               weight_decay=self.args.weight_decay_ae)
        scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
                    milestones=self.args.lr_milestones, gamma=0.1)
        
        ae.train()
        for epoch in range(self.args.num_epochs_ae):
            total_loss = 0
            for x, _ in Bar(self.train_loader):
                x = x.float().to(self.device)
                
                optimizer.zero_grad()
                x_hat = ae(x)
                reconst_loss = torch.mean(torch.sum((x_hat - x) ** 2, dim=tuple(range(1, x_hat.dim()))))
                reconst_loss.backward()
                optimizer.step()
                
                total_loss += reconst_loss.item()
            scheduler.step()
            print('Pretraining Autoencoder... Epoch: {}, Loss: {:.3f}'.format(
                   epoch, total_loss/len(self.train_loader)))
        self.save_weights_for_DeepSVDD(ae, self.train_loader) 
    

    def save_weights_for_DeepSVDD(self, model, dataloader):
        """Initialize Deep SVDD weights using the encoder weights of the pretrained autoencoder."""
        c = self.set_c(model, dataloader)
        net = network(self.args.latent_dim).to(self.device)
        state_dict = model.state_dict()
        net.load_state_dict(state_dict, strict=False)
        torch.save({'center': c.cpu().data.numpy().tolist(),
                    'net_dict': net.state_dict()}, '/content/drive/MyDrive/weights/pretrained_parameters.pth')
    

    def set_c(self, model, dataloader, eps=0.1):
        """Initializing the center for the hypersphere"""
        model.eval()
        z_ = []
        with torch.no_grad():
            for x, _ in dataloader:
                x = x.float().to(self.device)
                z = model.encode(x)
                z_.append(z.detach())
        z_ = torch.cat(z_)
        c = torch.mean(z_, dim=0)
        c[(abs(c) < eps) & (c < 0)] = -eps
        c[(abs(c) < eps) & (c > 0)] = eps
        return c


    def train(self):
        """Training the Deep SVDD model"""
        net = network().to(self.device)
        
        if self.args.pretrain==True:
            state_dict = torch.load('/content/drive/MyDrive/weights/pretrained_parameters.pth')
            net.load_state_dict(state_dict['net_dict'])
            c = torch.Tensor(state_dict['center']).to(self.device)
        else:
            net.apply(weights_init_normal)
            c = torch.randn(self.args.latent_dim).to(self.device)
        
        optimizer = optim.Adam(net.parameters(), lr=self.args.lr,
                               weight_decay=self.args.weight_decay)
        scheduler = optim.lr_scheduler.MultiStepLR(optimizer, 
                    milestones=self.args.lr_milestones, gamma=0.1)

        net.train()
        for epoch in range(self.args.num_epochs):
            total_loss = 0
            for x, _ in Bar(self.train_loader):
                x = x.float().to(self.device)

                optimizer.zero_grad()
                z = net(x)
                loss = torch.mean(torch.sum((z - c) ** 2, dim=1))
                loss.backward()
                optimizer.step()

                total_loss += loss.item()
            scheduler.step()
            print('Training Deep SVDD... Epoch: {}, Loss: {:.3f}'.format(
                   epoch, total_loss/len(self.train_loader)))
        self.net = net
        self.c = c

def eval(net, c, dataloader, device):
    """Testing the Deep SVDD model"""

    scores = []
    labels = []
    net.eval()
    print('Testing...')
    with torch.no_grad():
        for x, y in dataloader:
            x = x.float().to(device)
            z = net(x)
            score = torch.sum((z - c) ** 2, dim=1)

            scores.append(score.detach().cpu())
            labels.append(y.cpu())
    labels, scores = torch.cat(labels).numpy(), torch.cat(scores).numpy()
    print('ROC AUC score: {:.2f}'.format(roc_auc_score(labels, scores)*100))
    return labels, scores

class Args:
  def __init__(self, nclass):
    self.num_epochs=20
    self.num_epochs_ae=20
    self.patience=50
    self.lr=1e-4
    self.weight_decay=0.5e-6
    self.weight_decay_ae=0.5e-3
    self.lr_ae=1e-4
    self.lr_milestones=[50]
    self.batch_size=200
    self.pretrain=True
    self.latent_dim=32
    self.normal_class=nclass


nscores=[]
inscores=[]
outscores=[] 
for i in range(10):
  args = Args(i)
  device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
  data = get_mnist(args)
  deep_SVDD = TrainerDeepSVDD(args, data, device)
  if args.pretrain:
      deep_SVDD.pretrain()
  deep_SVDD.train()
  print("test for class  ",i,".....")
  labels, scores = eval(deep_SVDD.net, deep_SVDD.c, data[1], device)
  nscores.append(roc_auc_score(labels, scores)*100)
  inscores.append(scores[np.where(labels==0)[0]])
  outscores.append(scores[np.where(labels==1)[0]])
# Out:
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 136.714
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 104.588
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 78.497
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 58.625
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 44.314
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 34.643
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 28.044
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 23.422
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 20.087
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 17.614
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 15.720
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 14.227
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 13.044
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 12.065
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 11.243
# 5923/5923: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 15, Loss: 10.542
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 9.910
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 9.358
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 8.871
# 5923/5923: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 8.439
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.318
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.122
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.071
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.051
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.039
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.032
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.027
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.024
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.021
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.019
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.018
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.016
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.015
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.014
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.013
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.012
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.011
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.011
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.010
# 5923/5923: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.010
# test for class   0 .....
# Testing...
# ROC AUC score: 98.79
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 180.131
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 138.096
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 100.842
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 72.697
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 53.337
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 40.565
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 32.015
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 26.069
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 21.774
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 18.576
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 16.124
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 14.192
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 12.627
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 11.342
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 10.263
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 9.353
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 8.583
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 7.917
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 7.339
# 6742/6742: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 6.833
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.117
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.030
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.015
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.011
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.009
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.008
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.006
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.006
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.005
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.005
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.005
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.004
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.004
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.004
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.003
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.003
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.003
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.003
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.003
# 6742/6742: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.003
# test for class   1 .....
# Testing...
# ROC AUC score: 99.61
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 127.633
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 93.735
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 68.449
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 50.819
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 38.950
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 30.962
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 25.412
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 21.427
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 18.496
# 5958/5958: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 9, Loss: 16.289
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 14.571
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 13.208
# 5958/5958: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 12, Loss: 12.105
# 5958/5958: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 13, Loss: 11.203
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 10.453
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 9.811
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 9.261
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 8.788
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 8.372
# 5958/5958: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 8.005
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.288
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.122
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.072
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.049
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.037
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.030
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.025
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.022
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.019
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.017
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.016
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.014
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.013
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.012
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.012
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.011
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.010
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.010
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.009
# 5958/5958: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.009
# test for class   2 .....
# Testing...
# ROC AUC score: 91.34
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 128.527
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 94.085
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 68.971
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 51.605
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 39.510
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 31.115
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 25.265
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 21.097
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 18.062
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 15.776
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 14.010
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 12.631
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 11.523
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 10.616
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 9.868
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 9.247
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 8.722
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 8.270
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 7.882
# 6131/6131: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 7.541
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.321
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.152
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.094
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.065
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.048
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.038
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.031
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.026
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.023
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.020
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.018
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.017
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.015
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.014
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.013
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.013
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.011
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.011
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.010
# 6131/6131: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.010
# test for class   3 .....
# Testing...
# ROC AUC score: 90.24
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 148.849
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 113.099
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 84.893
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 63.747
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 48.924
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 38.687
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 31.467
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 26.343
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 22.616
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 19.813
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 17.630
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 15.918
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 14.529
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 13.424
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 12.485
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 11.715
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 11.022
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 10.471
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 9.959
# 5842/5842: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 9.506
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.190
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.084
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.052
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.038
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.030
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.025
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.021
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.019
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.016
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.015
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.013
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.013
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.011
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.010
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.010
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.009
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.009
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.008
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.008
# 5842/5842: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.007
# test for class   4 .....
# Testing...
# ROC AUC score: 92.39
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 116.213
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 85.252
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 62.501
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 46.967
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 36.519
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 29.475
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 24.580
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 21.057
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 18.358
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 16.342
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 14.727
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 13.421
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 12.375
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 11.520
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 10.786
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 10.166
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 9.634
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 9.138
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 8.730
# 5421/5421: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 8.411
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.254
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.116
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.071
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.053
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.041
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.033
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.028
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.027
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.023
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.020
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.018
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.018
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.016
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.014
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.013
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.013
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.012
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.011
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.010
# 5421/5421: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.011
# test for class   5 .....
# Testing...
# ROC AUC score: 85.28
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 136.933
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 104.483
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 78.222
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 58.018
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 44.102
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 34.908
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 28.540
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 24.014
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 20.751
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 18.328
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 16.453
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 14.978
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 13.782
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 12.784
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 11.955
# 5918/5918: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 15, Loss: 11.232
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 10.604
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 10.063
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 9.585
# 5918/5918: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 9.164
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.262
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.097
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.051
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.034
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.026
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.021
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.019
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.016
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.015
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.014
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.013
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.012
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.011
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.010
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.010
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.009
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.009
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.008
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.008
# 5918/5918: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.008
# test for class   6 .....
# Testing...
# ROC AUC score: 97.24
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 133.176
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 96.937
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 69.597
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 51.383
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 39.533
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 31.609
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 26.153
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 22.280
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 19.446
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 17.276
# 6265/6265: [===============================>] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 10, Loss: 15.585
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 14.233
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 13.129
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 12.197
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 11.402
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 10.732
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 10.115
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 9.597
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 9.115
# 6265/6265: [===============================>] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 8.683
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.193
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.073
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.041
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.029
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.023
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.020
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.017
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.015
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.013
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.012
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.011
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.010
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.009
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.009
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.008
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.007
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.007
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.007
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.007
# 6265/6265: [===============================>] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.006
# test for class   7 .....
# Testing...
# ROC AUC score: 95.32
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 153.155
# 5851/5851: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 1, Loss: 117.296
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 86.273
# 5851/5851: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 3, Loss: 63.462
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 47.827
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 37.257
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 30.053
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 25.030
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 21.429
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 18.769
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 16.725
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 15.122
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 13.817
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 12.769
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 11.902
# 5851/5851: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 15, Loss: 11.157
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 10.533
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 17, Loss: 10.014
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 9.534
# 5851/5851: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 9.100
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.159
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.064
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.038
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.028
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.022
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.019
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.017
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.014
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.013
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.011
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.010
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.010
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.009
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.008
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.008
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.007
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.007
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.006
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.006
# 5851/5851: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.006
# test for class   8 .....
# Testing...
# ROC AUC score: 94.78
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 0, Loss: 136.545
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 1, Loss: 101.694
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 2, Loss: 76.653
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 3, Loss: 58.677
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 4, Loss: 45.610
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 5, Loss: 36.544
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 6, Loss: 30.241
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 7, Loss: 25.719
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 8, Loss: 22.360
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 9, Loss: 19.789
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 10, Loss: 17.791
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 11, Loss: 16.208
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 12, Loss: 14.931
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 13, Loss: 13.871
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 14, Loss: 12.976
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 15, Loss: 12.212
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 16, Loss: 11.555
# 5949/5949: [==============================>.] - ETA 0.3s
# Pretraining Autoencoder... Epoch: 17, Loss: 10.972
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 18, Loss: 10.444
# 5949/5949: [==============================>.] - ETA 0.2s
# Pretraining Autoencoder... Epoch: 19, Loss: 9.958
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 0, Loss: 0.158
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 1, Loss: 0.065
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 2, Loss: 0.038
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 3, Loss: 0.027
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 4, Loss: 0.021
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 5, Loss: 0.017
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 6, Loss: 0.015
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 7, Loss: 0.013
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 8, Loss: 0.011
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 9, Loss: 0.010
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 10, Loss: 0.009
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 11, Loss: 0.009
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 12, Loss: 0.008
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 13, Loss: 0.008
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 14, Loss: 0.007
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 15, Loss: 0.007
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 16, Loss: 0.007
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 17, Loss: 0.006
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 18, Loss: 0.005
# 5949/5949: [==============================>.] - ETA 0.1s
# Training Deep SVDD... Epoch: 19, Loss: 0.005
# test for class   9 .....
# Testing...
# ROC AUC score: 95.85

# %%
for i in range(10):
  print("ROC scores for class ",i," is: ",nscores[i])
# Out:
# ROC scores for class  0  is:  98.79004706095299
# ROC scores for class  1  is:  99.60754439450295
# ROC scores for class  2  is:  91.3406906727797
# ROC scores for class  3  is:  90.24187491051664
# ROC scores for class  4  is:  92.38666816626986
# ROC scores for class  5  is:  85.27766453775423
# ROC scores for class  6  is:  97.23715100812308
# ROC scores for class  7  is:  95.31597221619877
# ROC scores for class  8  is:  94.77695282303326
# ROC scores for class  9  is:  95.8508558112126

# %%
for i in range(10):
  in_ = pd.DataFrame(inscores[i], columns=['Inlier'])
  out_ = pd.DataFrame(outscores[i], columns=['Outlier'])
  fig, ax = plt.subplots()
  in_.plot.kde(ax=ax, legend=True, title='Outliers vs Inliers for class '+str(i))
  out_.plot.kde(ax=ax, legend=True)
  plt.xlim(-0.05, 0.08)
  ax.grid(axis='x')
  ax.grid(axis='y')
  plt.show()
